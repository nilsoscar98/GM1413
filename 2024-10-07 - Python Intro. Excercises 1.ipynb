# %% [markdown]
# ### Pre-setup

# %%
import numpy as np

# %% [markdown]
# ### Exercise 1
# <b>Objective:</b> Write a Python program that prints the numbers from 1 to 100. But for multiples of 3, print "Fizz" instead of the number, and for the multiples of 5, print "Buzz." For numbers which are multiples of both 3 and 5, print "FizzBuzz.

# %%
numbers_in = np.arange(1, 101) #Creates a vector of numbers 1 through 100.
numbers_out = numbers_in.astype(str) #Creates an output vector like numbers_in

fizz = (numbers%3 == 0) #All indices in numbers_in that are 0 (mod 3).
buzz = (numbers%5 == 0) #All indices in numbers_in that are 0 (mod 5).

#Sets all the elements in 
numbers_out[fizz & buzz] = 'FizzBuzz'
numbers_out[fizz & ~buzz] = 'Fizz'
numbers_out[~fizz & buzz] = 'Buzz'

print(numbers_out)
# Out:
# ['1' '2' 'Fizz' '4' 'Buzz' 'Fizz' '7' '8' 'Fizz' 'Buzz' '11' 'Fizz' '13'
#  '14' 'FizzBuzz' '16' '17' 'Fizz' '19' 'Buzz' 'Fizz' '22' '23' 'Fizz'
#  'Buzz' '26' 'Fizz' '28' '29' 'FizzBuzz' '31' '32' 'Fizz' '34' 'Buzz'
#  'Fizz' '37' '38' 'Fizz' 'Buzz' '41' 'Fizz' '43' '44' 'FizzBuzz' '46' '47'
#  'Fizz' '49' 'Buzz' 'Fizz' '52' '53' 'Fizz' 'Buzz' '56' 'Fizz' '58' '59'
#  'FizzBuzz' '61' '62' 'Fizz' '64' 'Buzz' 'Fizz' '67' '68' 'Fizz' 'Buzz'
#  '71' 'Fizz' '73' '74' 'FizzBuzz' '76' '77' 'Fizz' '79' 'Buzz' 'Fizz' '82'
#  '83' 'Fizz' 'Buzz' '86' 'Fizz' '88' '89' 'FizzBuzz' '91' '92' 'Fizz' '94'
#  'Buzz' 'Fizz' '97' '98' 'Fizz' 'Buzz']
